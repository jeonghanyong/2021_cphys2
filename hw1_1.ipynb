# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
age = [12, 22, 25, 30, 33, 38, 41, 44, 49, 52, 55, 60, 65]
BMI = [15, 16, 22, 19, 34, 26, 38, 34, 36, 39, 29, 34, 32]
Pressure = [102, 120, 121, 123, 122, 120, 125, 129, 131, 130, 138, 136, 140]
diabetic = [0, 2, 4, 5, 10, 7, 30, 40, 45, 44, 60, 55, 64]

# %%
plt.scatter(age,diabetic)

# %%
plt.scatter(BMI,diabetic)

# %%
plt.scatter(Pressure,diabetic)

# %%
ㅜㅜ
