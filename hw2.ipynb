# %%
# 1. Sklearn 을 사용하지 않고

# %%
#2. Sklearn 을 이용한 방법
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
diabetes=datasets.load_diabetes()
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
diabetes.DESCR
# Out:
# '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n  :Number of Instances: 442\n\n  :Number of Attributes: First 10 columns are numeric predictive values\n\n  :Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n  :Attribute Information:\n      - age     age in years\n      - sex\n      - bmi     body mass index\n      - bp      average blood pressure\n      - s1      tc, T-Cells (a type of white blood cells)\n      - s2      ldl, low-density lipoproteins\n      - s3      hdl, high-density lipoproteins\n      - s4      tch, thyroid stimulating hormone\n      - s5      ltg, lamotrigine\n      - s6      glu, blood sugar level\n\nNote: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).\n\nSource URL:\nhttps://www4.stat.ncsu.edu/~boos/var.select/diabetes.html\n\nFor more information see:\nBradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.\n(https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)'

# %%
X_p=diabetes.data[:,2]
X_d = diabetes.target 
plt.plot(X_p,X_d,'.')

# %%
X_p=diabetes.data[:,2]
X_d = diabetes.target 
plt.plot(X_p,X_d,'.')

plt.scatter(X_p[0],X_d[1])
plt.plot([-0.05],[150],'r*')
plt.plot([0.05],[150],'k*')

# %%
from sklearn.cluster import datasets
datasets = datasets.load_diabetes()
diabetes.keys()

Xall=diabetes["data"] 
y=diabetes["target"]
X=[Xall[:,2],Xall[:,3]]
plt.scatter(X[0],X[1])

diabetes = diabetes(n_clusters = 2)
data = np.transpose(X_p)
diabetes.fit(data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-81-c047e73ec08c> in <module>
# ----> 1 from sklearn.cluster import datasets
#       2 datasets = datasets.load_diabetes()
#       3 diabetes.keys()
#       4
#       5 Xall=diabetes["data"]
#
# ImportError: cannot import name 'datasets' from 'sklearn.cluster' (C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\__init__.py)

# %%
temp=[]
for (i,j) in zip(X[0],X[1]):
    r1=(i-2)**2 + (j-0.5)**2
    r2=(i-4)**2 + (j-0.5)**2

    m=min(r1,r2)
    temp.append([r1,r2].index(m))
    n=n+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-307caab3fbdf> in <module>
#       1 temp=[]
# ----> 2 for (i,j) in zip(X[0],X[1]):
#       3     r1=(i-2)**2 + (j-0.5)**2
#       4     r2=(i-4)**2 + (j-0.5)**2
#       5
#
# NameError: name 'X' is not defined

# %%
x1=np.transpose([[i,j] for (t,i,j) in zip(temp,X[0],X[1]) if(t==0)])
x2=np.transpose([[i,j] for (t,i,j) in zip(temp,X[0],X[1]) if(t==1)])

r1=np.mean(x1[0]),np.mean(x1[1])
r2=np.mean(x2[0]),np.mean(x2[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-09044be82b15> in <module>
# ----> 1 x1=np.transpose([[i,j] for (t,i,j) in zip(temp,X[0],X[1]) if(t==0)])
#       2 x2=np.transpose([[i,j] for (t,i,j) in zip(temp,X[0],X[1]) if(t==1)])
#       3
#       4 r1=np.mean(x1[0]),np.mean(x1[1])
#       5 r2=np.mean(x2[0]),np.mean(x2[1])
#
# NameError: name 'X' is not defined

# %%
plt.scatter(X[0],X[1],c=temp)
plt.plot(r1[0],r1[1],'r*')
plt.plot(r2[0],r2[1],'k*')
plt.plot(r3[0],r3[1],'b*')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-080d75ce0003> in <module>
# ----> 1 plt.scatter(X[0],X[1],c=temp)
#       2 plt.plot(r1[0],r1[1],'r*')
#       3 plt.plot(r2[0],r2[1],'k*')
#       4 plt.plot(r3[0],r3[1],'b*')
#
# NameError: name 'X' is not defined
